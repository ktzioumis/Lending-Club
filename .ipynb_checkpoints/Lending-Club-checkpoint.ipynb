# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly as py
import plotly.graph_objects as go

# %%
df=pd.read_csv('loan.csv')
# Out:
# C:\kosta\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning:
#
# Columns (19,47,55,112,123,124,125,128,129,130,133,139,140,141) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
df.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN       2500         2500           2500.0   36 months
# 1 NaN        NaN      30000        30000          30000.0   60 months
# 2 NaN        NaN       5000         5000           5000.0   36 months
# 3 NaN        NaN       4000         4000           4000.0   36 months
# 4 NaN        NaN      30000        30000          30000.0   60 months
#
#    int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# 0     13.56        84.92     C        C1  ...                            NaN
# 1     18.94       777.23     D        D2  ...                            NaN
# 2     17.97       180.69     D        D1  ...                            NaN
# 3     18.94       146.51     D        D2  ...                            NaN
# 4     16.14       731.78     C        C4  ...                            NaN
#
#   hardship_last_payment_amount disbursement_method  debt_settlement_flag  \
# ...

# %%
df.shape
# Out:
# (2260668, 145)

# %%
df=df.drop(columns=['id','member_id','url'])

# %%
for col in df.columns:
    print(col)
# Out:
# loan_amnt
# funded_amnt
# funded_amnt_inv
# term
# int_rate
# installment
# grade
# sub_grade
# emp_title
# emp_length
# home_ownership
# annual_inc
# verification_status
# issue_d
# loan_status
# pymnt_plan
# desc
# purpose
# title
# zip_code
# addr_state
# dti
# delinq_2yrs
# earliest_cr_line
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# initial_list_status
# out_prncp
# out_prncp_inv
# total_pymnt
# total_pymnt_inv
# total_rec_prncp
# total_rec_int
# total_rec_late_fee
# recoveries
# collection_recovery_fee
# last_pymnt_d
# last_pymnt_amnt
# next_pymnt_d
# last_credit_pull_d
# collections_12_mths_ex_med
# mths_since_last_major_derog
# policy_code
# application_type
# annual_inc_joint
# dti_joint
# verification_status_joint
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_act_il
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# ...

# %%
lcdloanstats=pd.read_excel('LCDataDictionary.xlsx','LoanStats')

# %%
lcdloanstats
# Out:
#                LoanStatNew                                        Description
# 0           acc_now_delinq  The number of accounts on which the borrower i...
# 1     acc_open_past_24mths         Number of trades opened in past 24 months.
# 2               addr_state  The state provided by the borrower in the loan...
# 3                 all_util              Balance to credit limit on all trades
# 4               annual_inc  The self-reported annual income provided by th...
# ..                     ...                                                ...
# 148      settlement_amount  The loan amount that the borrower has agreed t...
# 149  settlement_percentage  The settlement amount as a percentage of the p...
# 150        settlement_term  The number of months that the borrower will be...
# 151                    NaN                                                NaN
# 152                    NaN  * Employer Title replaces Employer Name for al...
#
# [153 rows x 2 columns]

# %%
desc_columns=lcdloanstats.loc[lcdloanstats['LoanStatNew'].isin(df.columns)]

# %%
# df=df[desc_columns.LoanStatNew.values]

# %%
brows_cols=[]
for col in df.columns:
    if col not in desc_columns.values:
        brows_cols.append(col)
brows_cols
# Out:
# ['verification_status_joint',
#  'total_rev_hi_lim',
#  'revol_bal_joint',
#  'sec_app_earliest_cr_line',
#  'sec_app_inq_last_6mths',
#  'sec_app_mort_acc',
#  'sec_app_open_acc',
#  'sec_app_revol_util',
#  'sec_app_num_rev_accts',
#  'sec_app_chargeoff_within_12_mths',
#  'sec_app_collections_12_mths_ex_med',
#  'sec_app_mths_since_last_major_derog']

# %%
df[brows_cols].isna().sum()
# Out:
# verification_status_joint              2144938
# total_rev_hi_lim                         70276
# revol_bal_joint                        2152648
# sec_app_earliest_cr_line               2152647
# sec_app_inq_last_6mths                 2152647
# sec_app_mort_acc                       2152647
# sec_app_open_acc                       2152647
# sec_app_revol_util                     2154484
# sec_app_num_rev_accts                  2152647
# sec_app_chargeoff_within_12_mths       2152647
# sec_app_collections_12_mths_ex_med     2152647
# sec_app_mths_since_last_major_derog    2224726
# dtype: int64

# %%
df.dropna(axis='columns').columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'home_ownership',
#        'verification_status', 'issue_d', 'loan_status', 'pymnt_plan',
#        'purpose', 'addr_state', 'revol_bal', 'initial_list_status',
#        'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv',
#        'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_amnt', 'policy_code',
#        'application_type', 'hardship_flag', 'disbursement_method',
#        'debt_settlement_flag'],
#       dtype='object')

# %%
sum(df.funded_amnt==df.funded_amnt_inv)
# Out:
# 2109556

# %%
df.loc[df.funded_amnt!=df.funded_amnt_inv]
# Out:
#          loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 25           15000        15000          14975.0   60 months     14.47
# 38            6000         6000           5975.0   36 months      6.46
# 46            7500         7500           7475.0   36 months     11.80
# 47            7000         7000           6975.0   36 months     10.72
# 63            9000         9000           8975.0   36 months      6.46
# ...            ...          ...              ...         ...       ...
# 2260629      12225        12225          12175.0   36 months     21.45
# 2260632      16000        16000          15950.0   36 months     17.09
# 2260633      30000        30000          29725.0   60 months     30.17
# 2260642      32400        32400          32375.0   36 months     20.00
# 2260644      35000        35000          34725.0   60 months     30.75
#
#          installment grade sub_grade                    emp_title emp_length  \
# ...

# %%
df.loan_status.value_counts()
# Out:
# Fully Paid                                             1041952
# Current                                                 919695
# Charged Off                                             261655
# Late (31-120 days)                                       21897
# In Grace Period                                           8952
# Late (16-30 days)                                         3737
# Does not meet the credit policy. Status:Fully Paid        1988
# Does not meet the credit policy. Status:Charged Off        761
# Default                                                     31
# Name: loan_status, dtype: int64

# %%
# Out:
# 0         42
# 10318     17
# 257838    13
# 147873    11
# 257603     9
# 229670     6
# 6886       4
# 10319      2
# 255926     2
# 8264       2
# 6          2
# 9          1
# 196413     1
# 9541       1
# 162116     1
# 62         1
# 210991     1
# 9738       1
# 186156     1
# 259878     1
# 242724     1
# 261655     1
# 259651     1
# 1          1
# 25335      1
# 9814       1
# 10340      1
# 170979     1
# 2260       1
# 255945     1
# 257732     1
# 21693      1
# 9901       1
# 20394      1
# 147881     1
# 168        1
# 23442      1
# 127364     1
# 151418     1
# 4729       1
# 118        1
# 18282      1
# 10324      1
# dtype: int64

# %%
df[['hardship_status','hardship_loan_status']].groupby('hardship_loan_status').describe()
# Out:
#                      hardship_status
#                                count unique        top  freq
# hardship_loan_status
# Current                         2737      3  COMPLETED  2402
# In Grace Period                 2806      3  COMPLETED  1877
# Issued                            15      1  COMPLETED    15
# Late (16-30 days)               4622      3  COMPLETED  2956
# Late (31-120 days)               433      3  COMPLETED   291

# %%
df_col_desc=pd.DataFrame()
df_col_desc['Loan_Features']=df.columns
desc=[]
for col in df.columns:
    desc.append(lcdloanstats.loc[lcdloanstats['LoanStatNew']==col]['Description'].values.astype(str))
df_col_desc['Description']=desc
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-81-fa01a7328ed5> in <module>
#       3 desc=[]
#       4 for col in df.columns:
# ----> 5     desc.append(lcdloanstats.loc[lcdloanstats['LoanStatNew']==col]['Description'].values.astype(str)[0])
#       6 df_col_desc['Description']=desc
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
lcdloanstats.loc[lcdloanstats['LoanStatNew']==col]['Description'].values
# Out:
# array(['The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.'],
#       dtype=object)

# %%
df_col_desc['Description'][0][0]
# Out:
# 'The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.'

# %%
df_hardship=df.loc[df['hardship_status'].isna()==False]

# %%
notinloanstats
# Out:
# True

# %%
df_hardship['loan_status'].value_counts()
# Out:
# Charged Off           3817
# Current               3026
# Late (31-120 days)    1663
# Fully Paid            1518
# In Grace Period        384
# Late (16-30 days)      205
# Name: loan_status, dtype: int64

# %%
df_hardship['hardship_status'].value_counts()
# Out:
# COMPLETED    7541
# BROKEN       2187
# ACTIVE        885
# Name: hardship_status, dtype: int64

# %%
df_hardship.loc[df['loan_status']=='Charged Off']['hardship_status'].value_counts()
# Out:
# COMPLETED    2003
# BROKEN       1813
# ACTIVE          1
# Name: hardship_status, dtype: int64

# %%
desc
# Out:
# [41    The listed amount of the loan applied for by t...
#  Name: Description, dtype: object,
#  23    The total amount committed to that loan at tha...
#  Name: Description, dtype: object,
#  24    The total amount committed by investors for th...
#  Name: Description, dtype: object,
#  94    The number of payments on the loan. Values are...
#  Name: Description, dtype: object,
#  34    Interest Rate on the loan
#  Name: Description, dtype: object,
#  33    The monthly payment owed by the borrower if th...
#  Name: Description, dtype: object,
#  25    LC assigned loan grade
#  Name: Description, dtype: object,
#  92    LC assigned loan subgrade
#  Name: Description, dtype: object,
#  20    The job title supplied by the Borrower when ap...
#  Name: Description, dtype: object,
#  19    Employment length in years. Possible values ar...
#  Name: Description, dtype: object,
#  26    The home ownership status provided by the borr...
#  Name: Description, dtype: object,
# ...
